# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('insurance_data.csv')
df
# Out:
#     age  affordibility  bought_insurance
# 0    22              1                 0
# 1    25              0                 0
# 2    47              1                 1
# 3    52              0                 0
# 4    46              1                 1
# 5    56              1                 1
# 6    55              0                 0
# 7    60              0                 1
# 8    62              1                 1
# 9    61              1                 1
# 10   18              1                 0
# 11   28              1                 0
# 12   27              0                 0
# 13   29              0                 0
# 14   49              1                 1
# 15   55              1                 1
# 16   25              0                 1
# 17   58              1                 1
# 18   19              0                 0
# 19   18              1                 0
# 20   21              1                 0
# 21   26              0                 0
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,train_tragets,test_targets=train_test_split(df[['age','affordibility']],df.bought_insurance,test_size=0.2,random_state=42)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from sklearn.model_selection import train_test_split
#       2 x_train,x_test,train_tragets,test_targets=train_test_split(df[['age','affordibility']],df.bought_insurance,test_size=0.2,random_state=42)
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
len(x_train),len(x_test)
# Out:
# (22, 6)

# %%
x_train_scaled=x_train.copy()
x_test_scaled=x_test.copy()
x_train_scaled['age']=x_train_scaled['age']/100
x_test_scaled['age']=x_test_scaled['age']/100

# %%
x_test_scaled,x_train_scaled
# Out:
# (     age  affordibility
#  9   0.61              1
#  25  0.54              1
#  8   0.62              1
#  21  0.26              0
#  0   0.22              1
#  12  0.27              0,
#       age  affordibility
#  17  0.58              1
#  22  0.40              1
#  11  0.28              1
#  13  0.29              0
#  15  0.55              1
#  1   0.25              0
#  4   0.46              1
#  5   0.56              1
#  2   0.47              1
#  16  0.25              0
#  23  0.45              1
#  3   0.52              0
#  26  0.23              1
#  24  0.50              1
#  18  0.19              0
#  27  0.46              1
#  20  0.21              1
#  7   0.60              0
#  10  0.18              1
#  14  0.49              1
#  19  0.18              1
#  6   0.55              0)

# %%
model = keras.Sequential([
    keras.Input(shape=(2,)),
    keras.layers.Dense(10, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(x_train_scaled, train_tragets, epochs=500)
# Out:
# Epoch 1/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 884ms/step - accuracy: 0.6364 - loss: 0.7024
# Epoch 2/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6364 - loss: 0.7019
# Epoch 3/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6364 - loss: 0.7014
# Epoch 4/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6364 - loss: 0.7010
# Epoch 5/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6364 - loss: 0.7005
# Epoch 6/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6364 - loss: 0.7001
# Epoch 7/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6364 - loss: 0.6997
# Epoch 8/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6364 - loss: 0.6992
# Epoch 9/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6364 - loss: 0.6988
# Epoch 10/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6364 - loss: 0.6984
# Epoch 11/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6364 - loss: 0.6980
# Epoch 12/500
# ...
